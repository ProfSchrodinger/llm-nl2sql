# %%
import os
import json
import sqlite3
import re
import torch
import matplotlib.pyplot as plt

from torch.utils.data import Dataset, DataLoader
from transformers import T5Tokenizer, T5ForConditionalGeneration, get_linear_schedule_with_warmup
from peft import get_peft_model, LoraConfig, TaskType
from torch.optim import AdamW
from torch.amp import autocast, GradScaler
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm
from google.colab import drive

# %%
drive.mount('/content/drive')
spider_dir = "/content/drive/MyDrive/spider-upload"
# Out:
# Mounted at /content/drive

# %%
# load the training data
def load_spider_data(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)
    return data

# %%
training_data = load_spider_data(os.path.join(spider_dir, "train_spider.json"))

# %%
len(training_data)
# Out:
# 7000

# %%
def format_schema(db_id, tables_json):
    db_info = None
    for db in tables_json:
        if db['db_id'] == db_id:
            db_info = db
            break

    if not db_info:
        return "", {}

    # get tables present in each db
    tables = db_info['table_names_original']
    table_schema_text = []

    schema_dict = {
        'db_id': db_id,
        'tables': {}
    }

    for table_idx, table_name in enumerate(tables):
        columns = []
        table_dict = {
            'columns': [],
            'primary_keys': [],
            'foreign_keys': {}
        }

        # get columns in each table
        for col_idx, (tab_idx, col_name) in enumerate(db_info['column_names_original']):
            if tab_idx == table_idx and col_name != '*':
                # get column type
                col_type = db_info['column_types'][col_idx]

                # check primary key
                is_primary = col_idx in db_info['primary_keys']
                pk_marker = " [PK]" if is_primary else ""

                if is_primary:
                    table_dict['primary_keys'].append(col_name)

                # check foreign key
                fk_info = ""
                for fk_col1, fk_col2 in db_info['foreign_keys']:
                    if col_idx == fk_col1 or col_idx == fk_col2:
                        # Find the other table/column in the relationship
                        other_col_idx = fk_col2 if col_idx == fk_col1 else fk_col1
                        other_tab_idx = db_info['column_names_original'][other_col_idx][0]
                        other_col_name = db_info['column_names_original'][other_col_idx][1]
                        other_tab_name = tables[other_tab_idx]

                        fk_info = f" [FK -> {other_tab_name}.{other_col_name}]"

                        table_dict['foreign_keys'][col_name] = {
                            'table': other_tab_name,
                            'column': other_col_name
                        }
                        break

                columns.append(f"{col_name} ({col_type}){pk_marker}{fk_info}")

                table_dict['columns'].append({
                    'name': col_name,
                    'type': col_type,
                    'is_primary_key': is_primary,
                    'is_foreign_key': bool(fk_info)
                })

        # Create the table schema text
        if columns:
            cols_text = ", ".join(columns)
            table_schema_text.append(f"Table: {table_name} ({cols_text})")
            schema_dict['tables'][table_name] = table_dict

    schema_text = "\n".join(table_schema_text)

    return schema_text, schema_dict

# %%
# load schemas from tables.json file
def load_all_schemas(tables_json_path):
    with open(tables_json_path, 'r') as f:
        tables_json = json.load(f)

    # test with 5 tables
    # tables_json = tables_json[:5]

    text_schema_dict = {}
    struct_schema_dict = {}
    db_ids = set(db['db_id'] for db in tables_json)

    for db_id in db_ids:
        schema_text, schema_dict = format_schema(db_id, tables_json)
        text_schema_dict[db_id] = schema_text
        struct_schema_dict[db_id] = schema_dict

    print(f"Loaded schema information for {len(struct_schema_dict)} databases")
    return text_schema_dict, struct_schema_dict

# %%
text_schema_dict, struct_schema_dict = load_all_schemas(os.path.join(spider_dir, "tables.json"))
# Out:
# Loaded schema information for 166 databases

# %%
text_schema_dict
# Out:
# {'soccer_2': 'Table: College (cName (text) [PK] [FK -> Tryout.cName], state (text), enr (number))\nTable: Player (pID (number) [PK] [FK -> Tryout.pID], pName (text), yCard (text), HS (number))\nTable: Tryout (pID (number) [PK] [FK -> Player.pID], cName (text) [FK -> College.cName], pPos (text), decision (text))',
#  'school_bus': 'Table: driver (Driver_ID (number) [PK] [FK -> school_bus.Driver_ID], Name (text), Party (text), Home_city (text), Age (number))\nTable: school (School_ID (number) [PK] [FK -> school_bus.School_ID], Grade (text), School (text), Location (text), Type (text))\nTable: school_bus (School_ID (number) [PK] [FK -> school.School_ID], Driver_ID (number) [FK -> driver.Driver_ID], Years_Working (number), If_full_time (others))',
#  'orchestra': 'Table: conductor (Conductor_ID (number) [PK] [FK -> orchestra.Conductor_ID], Name (text), Age (number), Nationality (text), Year_of_Work (number))\nTable: orchestra (Orchestra_ID (number) [PK] [FK -> performance.Orchestra_ID], Orchestra (text), Conductor_ID (number) [FK -> conductor.Conductor_ID], Record_Company (text), Year_of_Founded (number), Major_Record_Format (text))\nTable: performance (Performance_ID (number) [PK] [FK -> show.Performance_ID], Orchestra_ID (number) [FK -> orchestra.Orchestra_ID], Type (text), Date (text), Official_ratings_(millions) (number), Weekly_rank (text), Share (text))\nTable: show (Show_ID (number), Performance_ID (number) [FK -> performance.Performance_ID], If_first_show (others), Result (text), Attendance (number))',
#  'real_estate_properties': 'Table: Ref_Feature_Types (feature_type_code (text) [PK] [FK -> Other_Available_Features.feature_type_code], feature_type_name (text))\nTable: Ref_Property_Types (property_type_code (text) [PK] [FK -> Properties.property_type_code], property_type_description (text))\nTable: Other_Available_Features (feature_id (number) [PK] [FK -> Other_Property_Features.feature_id], feature_type_code (text) [FK -> Ref_Feature_Types.feature_type_code], feature_name (text), feature_description (text))\nTable: Properties (property_id (number) [PK] [FK -> Other_Property_Features.property_id], property_type_code (text) [FK -> Ref_Property_Types.property_type_code], date_on_market (time), date_sold (time), property_name (text), property_address (text), room_count (number), vendor_requested_price (number), buyer_offered_price (number), agreed_selling_price (number), apt_feature_1 (text), apt_feature_2 (text), apt_feature_3 (text), fld_feature_1 (text), fld_feature_2 (text), fld_feature_3 (text), hse_feature_1 (text), hse_feature_2 (text), hse_feature_3 (text), oth_feature_1 (text), oth_feature_2 (text), oth_feature_3 (text), shp_feature_1 (text), shp_feature_2 (text), shp_feature_3 (text), other_property_details (text))\nTable: Other_Property_Features (property_id (number) [FK -> Properties.property_id], feature_id (number) [FK -> Other_Available_Features.feature_id], property_feature_description (text))',
#  'flight_4': 'Table: routes (rid (number) [PK], dst_apid (number) [FK -> airports.apid], dst_ap (text), src_apid (number) [FK -> airports.apid], src_ap (text), alid (number) [FK -> airlines.alid], airline (text), codeshare (text))\nTable: airports (apid (number) [PK] [FK -> routes.src_apid], name (text), city (text), country (text), x (number), y (number), elevation (number), iata (text), icao (text))\nTable: airlines (alid (number) [PK] [FK -> routes.alid], name (text), iata (text), icao (text), callsign (text), country (text), active (text))',
#  'insurance_and_eClaims': 'Table: Customers (Customer_ID (number) [PK] [FK -> Policies.Customer_ID], Customer_Details (text))\nTable: Staff (Staff_ID (number) [PK] [FK -> Claims_Documents.Created_by_Staff_ID], Staff_Details (text))\nTable: Policies (Policy_ID (number) [PK] [FK -> Claim_Headers.Policy_ID], Customer_ID (number) [FK -> Customers.Customer_ID], Policy_Type_Code (text), Start_Date (time), End_Date (time))\nTable: Claim_Headers (Claim_Header_ID (number) [PK] [FK -> Claims_Documents.Claim_ID], Claim_Status_Code (text), Claim_Type_Code (text), Policy_ID (number) [FK -> Policies.Policy_ID], Date_of_Claim (time), Date_of_Settlement (time), Amount_Claimed (number), Amount_Piad (number))\nTable: Claims_Documents (Claim_ID (number) [PK] [FK -> Claim_Headers.Claim_Header_ID], Document_Type_Code (text), Created_by_Staff_ID (number) [FK -> Staff.Staff_ID], Created_Date (number))\nTable: Claims_Processing_Stages (Claim_Stage_ID (number) [PK], Next_Claim_Stage_ID (number), Claim_Status_Name (text), Claim_Status_Description (text))\nTable: Claims_Processing (Claim_Processing_ID (number) [PK], Claim_ID (number) [FK -> Claim_Headers.Claim_Header_ID], Claim_Outcome_Code (text), Claim_Stage_ID (number), Staff_ID (number) [FK -> Staff.Staff_ID])',
#  'csu_1': 'Table: Campuses (Id (number) [PK] [FK -> csu_fees.Campus], Campus (text), Location (text), County (text), Year (number))\nTable: csu_fees (Campus (number) [PK] [FK -> Campuses.Id], Year (number), CampusFee (number))\nTable: degrees (Year (number) [PK], Campus (number) [FK -> Campuses.Id], Degrees (number))\nTable: discipline_enrollments (Campus (number) [PK] [FK -> Campuses.Id], Discipline (number), Year (number), Undergraduate (number), Graduate (number))\nTable: enrollments (Campus (number) [PK] [FK -> Campuses.Id], Year (number), TotalEnrollment_AY (number), FTE_AY (number))\nTable: faculty (Campus (number) [FK -> Campuses.Id], Year (number), Faculty (number))',
#  'election': 'Table: county (County_Id (number) [PK] [FK -> election.District], County_name (text), Population (number), Zip_code (text))\nTable: party (Party_ID (number) [PK] [FK -> election.Party], Year (number), Party (text), Governor (text), Lieutenant_Governor (text), Comptroller (text), Attorney_General (text), US_Senate (text))\nTable: election (Election_ID (number) [PK], Counties_Represented (text), District (number) [FK -> county.County_Id], Delegate (text), Party (number) [FK -> party.Party_ID], First_Elected (number), Committee (text))',
#  'college_2': 'Table: classroom (building (text) [PK] [FK -> section.building], room_number (text) [FK -> section.room_number], capacity (number))\nTable: department (dept_name (text) [PK] [FK -> course.dept_name], building (text), budget (number))\nTable: course (course_id (text) [PK] [FK -> section.course_id], title (text), dept_name (text) [FK -> department.dept_name], credits (number))\nTable: instructor (ID (text) [PK] [FK -> teaches.ID], name (text), dept_name (text) [FK -> department.dept_name], salary (number))\nTable: section (course_id (text) [PK] [FK -> course.course_id], sec_id (text) [FK -> teaches.sec_id], semester (text) [FK -> teaches.semester], year (number) [FK -> teaches.year], building (text) [FK -> classroom.building], room_number (text) [FK -> classroom.room_number], time_slot_id (text))\nTable: teaches (ID (text) [PK] [FK -> instructor.ID], course_id (text) [FK -> section.course_id], sec_id (text) [FK -> section.sec_id], semester (text) [FK -> section.semester], year (number) [FK -> section.year])\nTable: student (ID (text) [PK] [FK -> takes.ID], name (text), dept_name (text) [FK -> department.dept_name], tot_cred (number))\nTable: takes (ID (text) [PK] [FK -> student.ID], course_id (text) [FK -> section.course_id], sec_id (text) [FK -> section.sec_id], semester (text) [FK -> section.semester], year (number) [FK -> section.year], grade (text))\nTable: advisor (s_ID (text) [PK] [FK -> student.ID], i_ID (text) [FK -> instructor.ID])\nTable: time_slot (time_slot_id (text) [PK], day (text), start_hr (number), start_min (number), end_hr (number), end_min (number))\nTable: prereq (course_id (text) [PK] [FK -> course.course_id], prereq_id (text) [FK -> course.course_id])',
#  'candidate_poll': 'Table: candidate (Candidate_ID (number) [PK], People_ID (number) [FK -> people.People_ID], Poll_Source (text), Date (text), Support_rate (number), Consider_rate (number), Oppose_rate (number), Unsure_rate (number))\nTable: people (People_ID (number) [PK] [FK -> candidate.People_ID], Sex (text), Name (text), Date_of_Birth (text), Height (number), Weight (number))',
#  'loan_1': 'Table: bank (branch_ID (number) [PK] [FK -> customer.branch_ID], bname (text), no_of_customers (number), city (text), state (text))\nTable: customer (cust_ID (text) [PK], cust_name (text), acc_type (text), acc_bal (number), no_of_loans (number), credit_score (number), branch_ID (number) [FK -> bank.branch_ID], state (text))\nTable: loan (loan_ID (text) [PK], loan_type (text), cust_ID (text), branch_ID (text) [FK -> bank.branch_ID], amount (number))',
#  'customer_deliveries': 'Table: Products (product_id (number) [PK] [FK -> Regular_Order_Products.product_id], product_name (text), product_price (number), product_description (text))\nTable: Addresses (address_id (number) [PK] [FK -> Customer_Addresses.address_id], address_details (text), city (text), zip_postcode (text), state_province_county (text), country (text))\nTable: Customers (customer_id (number) [PK] [FK -> Regular_Orders.distributer_id], payment_method (text), customer_name (text), customer_phone (text), customer_email (text), date_became_customer (time))\nTable: Regular_Orders (regular_order_id (number) [PK] [FK -> Regular_Order_Products.regular_order_id], distributer_id (number) [FK -> Customers.customer_id])\nTable: Regular_Order_Products (regular_order_id (number) [FK -> Regular_Orders.regular_order_id], product_id (number) [FK -> Products.product_id])\nTable: Actual_Orders (actual_order_id (number) [PK] [FK -> Actual_Order_Products.actual_order_id], order_status_code (text), regular_order_id (number) [FK -> Regular_Orders.regular_order_id], actual_order_date (time))\nTable: Actual_Order_Products (actual_order_id (number) [FK -> Actual_Orders.actual_order_id], product_id (number) [FK -> Products.product_id])\nTable: Customer_Addresses (customer_id (number) [FK -> Customers.customer_id], address_id (number) [FK -> Addresses.address_id], date_from (time), address_type (text), date_to (time))\nTable: Delivery_Routes (route_id (number) [PK] [FK -> Delivery_Route_Locations.route_id], route_name (text), other_route_details (text))\nTable: Delivery_Route_Locations (location_code (text) [PK] [FK -> Order_Deliveries.location_code], route_id (number) [FK -> Delivery_Routes.route_id], location_address_id (number) [FK -> Addresses.address_id], location_name (text))\nTable: Trucks (truck_id (number) [PK] [FK -> Order_Deliveries.truck_id], truck_licence_number (text), truck_details (text))\nTable: Employees (employee_id (number) [PK] [FK -> Order_Deliveries.driver_employee_id], employee_address_id (number) [FK -> Addresses.address_id], employee_name (text), employee_phone (text))\nTable: Order_Deliveries (location_code (text) [FK -> Delivery_Route_Locations.location_code], actual_order_id (number) [FK -> Actual_Orders.actual_order_id], delivery_status_code (text), driver_employee_id (number) [FK -> Employees.employee_id], truck_id (number) [FK -> Trucks.truck_id], delivery_date (time))',
#  'entertainment_awards': 'Table: festival_detail (Festival_ID (number) [PK] [FK -> nomination.Festival_ID], Festival_Name (text), Chair_Name (text), Location (text), Year (number), Num_of_Audience (number))\nTable: artwork (Artwork_ID (number) [PK] [FK -> nomination.Artwork_ID], Type (text), Name (text))\nTable: nomination (Artwork_ID (number) [PK] [FK -> artwork.Artwork_ID], Festival_ID (number) [FK -> festival_detail.Festival_ID], Result (text))',
#  'riding_club': 'Table: player (Player_ID (number) [PK] [FK -> player_coach.Player_ID], Sponsor_name (text), Player_name (text), Gender (text), Residence (text), Occupation (text), Votes (number), Rank (text))\nTable: club (Club_ID (number) [PK] [FK -> coach.Club_ID], Club_name (text), Region (text), Start_year (number))\nTable: coach (Coach_ID (number) [PK] [FK -> player_coach.Coach_ID], Coach_name (text), Gender (text), Club_ID (number) [FK -> club.Club_ID], Rank (number))\nTable: player_coach (Player_ID (number) [PK] [FK -> player.Player_ID], Coach_ID (number) [FK -> coach.Coach_ID], Starting_year (number))\nTable: match_result (Rank (number) [PK], Club_ID (number) [FK -> club.Club_ID], Gold (number), Big_Silver (number), Small_Silver (number), Bronze (number), Points (number))',
#  'music_1': 'Table: genre (g_name (text) [PK] [FK -> artist.preferred_genre], rating (text), most_popular_in (text))\nTable: artist (artist_name (text) [PK] [FK -> files.artist_name], country (text), gender (text), preferred_genre (text) [FK -> genre.g_name])\nTable: files (f_id (number) [PK] [FK -> song.f_id], artist_name (text) [FK -> artist.artist_name], file_size (text), duration (text), formats (text))\nTable: song (song_name (text) [PK], artist_name (text) [FK -> artist.artist_name], country (text), f_id (number) [FK -> files.f_id], genre_is (text) [FK -> genre.g_name], rating (number), languages (text), releasedate (time), resolution (number))',
#  'book_2': 'Table: publication (Publication_ID (number) [PK], Book_ID (number) [FK -> book.Book_ID], Publisher (text), Publication_Date (text), Price (number))\nTable: book (Book_ID (number) [PK] [FK -> publication.Book_ID], Title (text), Issues (number), Writer (text))',
#  'ship_1': 'Table: captain (Captain_ID (number) [PK], Name (text), Ship_ID (number) [FK -> Ship.Ship_ID], age (text), Class (text), Rank (text))\nTable: Ship (Ship_ID (number) [PK] [FK -> captain.Ship_ID], Name (text), Type (text), Built_Year (number), Class (text), Flag (text))',
#  'restaurants': 'Table: GEOGRAPHIC (CITY_NAME (text) [PK] [FK -> RESTAURANT.CITY_NAME], COUNTY (text), REGION (text))\nTable: RESTAURANT (ID (number) [PK], NAME (text), FOOD_TYPE (text), CITY_NAME (text) [FK -> GEOGRAPHIC.CITY_NAME], RATING (number))\nTable: LOCATION (RESTAURANT_ID (number) [PK], HOUSE_NUMBER (number), STREET_NAME (text), CITY_NAME (text) [FK -> GEOGRAPHIC.CITY_NAME])',
#  'movie_1': 'Table: Movie (mID (number) [PK] [FK -> Rating.mID], title (text), year (number), director (text))\nTable: Reviewer (rID (number) [PK] [FK -> Rating.rID], name (text))\nTable: Rating (rID (number) [FK -> Reviewer.rID], mID (number) [FK -> Movie.mID], stars (number), ratingDate (time))',
#  'station_weather': 'Table: train (id (number) [PK] [FK -> route.train_id], train_number (number), name (text), origin (text), destination (text), time (text), interval (text))\nTable: station (id (number) [PK] [FK -> route.station_id], network_name (text), services (text), local_authority (text))\nTable: route (train_id (number) [PK] [FK -> train.id], station_id (number) [FK -> station.id])\nTable: weekly_weather (station_id (number) [PK] [FK -> station.id], day_of_week (text), high_temperature (number), low_temperature (number), precipitation (number), wind_speed_mph (number))',
#  'network_2': 'Table: Person (name (text) [PK] [FK -> PersonFriend.friend], age (number), city (text), gender (text), job (text))\nTable: PersonFriend (name (text) [FK -> Person.name], friend (text) [FK -> Person.name], year (number))',
#  'manufacturer': 'Table: manufacturer (Manufacturer_ID (number) [PK] [FK -> furniture_manufacte.Manufacturer_ID], Open_Year (number), Name (text), Num_of_Factories (number), Num_of_Shops (number))\nTable: furniture (Furniture_ID (number) [PK] [FK -> furniture_manufacte.Furniture_ID], Name (text), Num_of_Component (number), Market_Rate (number))\nTable: furniture_manufacte (Manufacturer_ID (number) [PK] [FK -> manufacturer.Manufacturer_ID], Furniture_ID (number) [FK -> furniture.Furniture_ID], Price_in_Dollar (number))',
#  'device': 'Table: device (Device_ID (number) [PK] [FK -> stock.Device_ID], Device (text), Carrier (text), Package_Version (text), Applications (text), Software_Platform (text))\nTable: shop (Shop_ID (number) [PK] [FK -> stock.Shop_ID], Shop_Name (text), Location (text), Open_Date (text), Open_Year (number))\nTable: stock (Shop_ID (number) [PK] [FK -> shop.Shop_ID], Device_ID (number) [FK -> device.Device_ID], Quantity (number))',
#  'small_bank_1': 'Table: ACCOUNTS (custid (number) [PK] [FK -> SAVINGS.custid], name (text))\nTable: SAVINGS (custid (number) [PK] [FK -> ACCOUNTS.custid], balance (number))\nTable: CHECKING (custid (number) [PK] [FK -> ACCOUNTS.custid], balance (number))',
#  'journal_committee': 'Table: journal (Journal_ID (number) [PK] [FK -> journal_committee.Journal_ID], Date (text), Theme (text), Sales (number))\nTable: editor (Editor_ID (number) [PK] [FK -> journal_committee.Editor_ID], Name (text), Age (number))\nTable: journal_committee (Editor_ID (number) [PK] [FK -> editor.Editor_ID], Journal_ID (number) [FK -> journal.Journal_ID], Work_Type (text))',
#  'storm_record': 'Table: storm (Storm_ID (number) [PK] [FK -> affected_region.Storm_ID], Name (text), Dates_active (text), Max_speed (number), Damage_millions_USD (number), Number_Deaths (number))\nTable: region (Region_id (number) [PK] [FK -> affected_region.Region_id], Region_code (text), Region_name (text))\nTable: affected_region (Region_id (number) [PK] [FK -> region.Region_id], Storm_ID (number) [FK -> storm.Storm_ID], Number_city_affected (number))',
#  'restaurant_1': 'Table: Student (StuID (number) [PK] [FK -> Visits_Restaurant.StuID], LName (text), Fname (text), Age (number), Sex (text), Major (number), Advisor (number), city_code (text))\nTable: Restaurant (ResID (number) [PK] [FK -> Type_Of_Restaurant.ResID], ResName (text), Address (text), Rating (number))\nTable: Type_Of_Restaurant (ResID (number) [FK -> Restaurant.ResID], ResTypeID (number) [FK -> Restaurant_Type.ResTypeID])\nTable: Restaurant_Type (ResTypeID (number) [PK] [FK -> Type_Of_Restaurant.ResTypeID], ResTypeName (text), ResTypeDescription (text))\nTable: Visits_Restaurant (StuID (number) [FK -> Student.StuID], ResID (number) [FK -> Restaurant.ResID], Time (time), Spent (number))',
#  'local_govt_and_lot': 'Table: Customers (customer_id (number) [PK] [FK -> Customer_Events.customer_id], customer_details (text))\nTable: Properties (property_id (number) [PK] [FK -> Residents.property_id], property_type_code (text), property_address (text), other_details (text))\nTable: Residents (resident_id (number) [PK] [FK -> Residents_Services.resident_id], property_id (number) [FK -> Properties.property_id], date_moved_in (time) [FK -> Residents_Services.date_moved_in], date_moved_out (time), other_details (text))\nTable: Organizations (organization_id (number) [PK] [FK -> Services.organization_id], parent_organization_id (number), organization_details (text))\nTable: Services (service_id (number) [PK] [FK -> Residents_Services.service_id], organization_id (number) [FK -> Organizations.organization_id], service_type_code (text), service_details (text))\nTable: Residents_Services (resident_id (number) [PK] [FK -> Residents.resident_id], service_id (number) [FK -> Services.service_id], date_moved_in (time) [FK -> Residents.date_moved_in], property_id (number) [FK -> Residents.property_id], date_requested (time), date_provided (time), other_details (text))\nTable: Things (thing_id (number) [PK] [FK -> Customer_Events.thing_id], organization_id (number) [FK -> Organizations.organization_id], Type_of_Thing_Code (text), service_type_code (text), service_details (text))\nTable: Customer_Events (Customer_Event_ID (number) [PK] [FK -> Customer_Event_Notes.Customer_Event_ID], customer_id (number) [FK -> Customers.customer_id], date_moved_in (time) [FK -> Residents.date_moved_in], property_id (number) [FK -> Residents.property_id], resident_id (number) [FK -> Residents.resident_id], thing_id (number) [FK -> Things.thing_id])\nTable: Customer_Event_Notes (Customer_Event_Note_ID (number) [PK], Customer_Event_ID (number) [FK -> Customer_Events.Customer_Event_ID], service_type_code (text), resident_id (number), property_id (number), date_moved_in (time))\nTable: Timed_Status_of_Things (thing_id (number) [PK] [FK -> Things.thing_id], Date_and_Date (time), Status_of_Thing_Code (text))\nTable: Timed_Locations_of_Things (thing_id (number) [PK] [FK -> Things.thing_id], Date_and_Time (time), Location_Code (text))',
#  'train_station': 'Table: station (Station_ID (number) [PK] [FK -> train_station.Station_ID], Name (text), Annual_entry_exit (number), Annual_interchanges (number), Total_Passengers (number), Location (text), Main_Services (text), Number_of_Platforms (number))\nTable: train (Train_ID (number) [PK] [FK -> train_station.Train_ID], Name (text), Time (text), Service (text))\nTable: train_station (Train_ID (number) [PK] [FK -> train.Train_ID], Station_ID (number) [FK -> station.Station_ID])',
#  'ship_mission': 'Table: mission (Mission_ID (number) [PK], Ship_ID (number) [FK -> ship.Ship_ID], Code (text), Launched_Year (number), Location (text), Speed_knots (number), Fate (text))\nTable: ship (Ship_ID (number) [PK] [FK -> mission.Ship_ID], Name (text), Type (text), Nationality (text), Tonnage (number))',
#  'e_government': 'Table: Addresses (address_id (number) [PK] [FK -> Party_Addresses.address_id], line_1_number_building (text), town_city (text), zip_postcode (text), state_province_county (text), country (text))\nTable: Services (service_id (number) [PK] [FK -> Forms.service_id], service_type_code (text), service_name (text), service_descriptio (text))\nTable: Forms (form_id (number) [PK] [FK -> Party_Forms.form_id], form_type_code (text), service_id (number) [FK -> Services.service_id], form_number (text), form_name (text), form_description (text))\nTable: Individuals (individual_id (number) [PK] [FK -> Organization_Contact_Individuals.individual_id], individual_first_name (text), individual_middle_name (text), inidividual_phone (text), individual_email (text), individual_address (text), individual_last_name (text))\nTable: Organizations (organization_id (number) [PK] [FK -> Organization_Contact_Individuals.organization_id], date_formed (time), organization_name (text), uk_vat_number (text))\nTable: Parties (party_id (number) [PK] [FK -> Party_Addresses.party_id], payment_method_code (text), party_phone (text), party_email (text))\nTable: Organization_Contact_Individuals (individual_id (number) [PK] [FK -> Individuals.individual_id], organization_id (number) [FK -> Organizations.organization_id], date_contact_from (time), date_contact_to (time))\nTable: Party_Addresses (party_id (number) [PK] [FK -> Parties.party_id], address_id (number) [FK -> Addresses.address_id], date_address_from (time), address_type_code (text), date_address_to (time))\nTable: Party_Forms (party_id (number) [PK] [FK -> Parties.party_id], form_id (number) [FK -> Forms.form_id], date_completion_started (time), form_status_code (text), date_fully_completed (time))\nTable: Party_Services (booking_id (number), customer_id (number) [FK -> Parties.party_id], service_id (number) [FK -> Services.service_id], service_datetime (time), booking_made_date (time))',
#  'flight_1': 'Table: flight (flno (number) [PK], origin (text), destination (text), distance (number), departure_date (time), arrival_date (time), price (number), aid (number) [FK -> aircraft.aid])\nTable: aircraft (aid (number) [PK] [FK -> flight.aid], name (text), distance (number))\nTable: employee (eid (number) [PK] [FK -> certificate.eid], name (text), salary (number))\nTable: certificate (eid (number) [PK] [FK -> employee.eid], aid (number) [FK -> aircraft.aid])',
#  'battle_death': 'Table: battle (id (number) [PK] [FK -> ship.lost_in_battle], name (text), date (text), bulgarian_commander (text), latin_commander (text), result (text))\nTable: ship (lost_in_battle (number) [FK -> battle.id], id (number) [PK] [FK -> death.caused_by_ship_id], name (text), tonnage (text), ship_type (text), location (text), disposition_of_ship (text))\nTable: death (caused_by_ship_id (number) [FK -> ship.id], id (number) [PK], note (text), killed (number), injured (number))',
#  'shop_membership': 'Table: member (Member_ID (number) [PK] [FK -> membership_register_branch.Member_ID], Card_Number (text), Name (text), Hometown (text), Level (number))\nTable: branch (Branch_ID (number) [PK] [FK -> membership_register_branch.Branch_ID], Name (text), Open_year (text), Address_road (text), City (text), membership_amount (text))\nTable: membership_register_branch (Member_ID (number) [PK] [FK -> member.Member_ID], Branch_ID (text) [FK -> branch.Branch_ID], Register_Year (text))\nTable: purchase (Member_ID (number) [PK] [FK -> member.Member_ID], Branch_ID (text) [FK -> branch.Branch_ID], Year (text), Total_pounds (number))',
#  'cre_Doc_Control_Systems': 'Table: Ref_Document_Types (document_type_code (text) [PK] [FK -> Documents.document_type_code], document_type_description (text))\nTable: Roles (role_code (text) [PK] [FK -> Employees.role_code], role_description (text))\nTable: Addresses (address_id (number) [PK] [FK -> Documents_Mailed.mailed_to_address_id], address_details (text))\nTable: Ref_Document_Status (document_status_code (text) [PK] [FK -> Documents.document_status_code], document_status_description (text))\nTable: Ref_Shipping_Agents (shipping_agent_code (text) [PK] [FK -> Documents.shipping_agent_code], shipping_agent_name (text), shipping_agent_description (text))\nTable: Documents (document_id (number) [PK] [FK -> Document_Drafts.document_id], document_status_code (text) [FK -> Ref_Document_Status.document_status_code], document_type_code (text) [FK -> Ref_Document_Types.document_type_code], shipping_agent_code (text) [FK -> Ref_Shipping_Agents.shipping_agent_code], receipt_date (time), receipt_number (text), other_details (text))\nTable: Employees (employee_id (number) [PK] [FK -> Circulation_History.employee_id], role_code (text) [FK -> Roles.role_code], employee_name (text), other_details (text))\nTable: Document_Drafts (document_id (number) [PK] [FK -> Documents.document_id], draft_number (number) [FK -> Draft_Copies.draft_number], draft_details (text))\nTable: Draft_Copies (document_id (number) [PK] [FK -> Document_Drafts.document_id], draft_number (number) [FK -> Document_Drafts.draft_number], copy_number (number) [FK -> Circulation_History.copy_number])\nTable: Circulation_History (document_id (number) [PK] [FK -> Draft_Copies.document_id], draft_number (number) [FK -> Draft_Copies.draft_number], copy_number (number) [FK -> Draft_Copies.copy_number], employee_id (number) [FK -> Employees.employee_id])\nTable: Documents_Mailed (document_id (number) [PK] [FK -> Documents.document_id], mailed_to_address_id (number) [FK -> Addresses.address_id], mailing_date (time))',
#  'concert_singer': 'Table: stadium (Stadium_ID (number) [PK] [FK -> concert.Stadium_ID], Location (text), Name (text), Capacity (number), Highest (number), Lowest (number), Average (number))\nTable: singer (Singer_ID (number) [PK] [FK -> singer_in_concert.Singer_ID], Name (text), Country (text), Song_Name (text), Song_release_year (text), Age (number), Is_male (others))\nTable: concert (concert_ID (number) [PK] [FK -> singer_in_concert.concert_ID], concert_Name (text), Theme (text), Stadium_ID (text) [FK -> stadium.Stadium_ID], Year (text))\nTable: singer_in_concert (concert_ID (number) [PK] [FK -> concert.concert_ID], Singer_ID (text) [FK -> singer.Singer_ID])',
#  'roller_coaster': 'Table: roller_coaster (Roller_Coaster_ID (number) [PK], Name (text), Park (text), Country_ID (number) [FK -> country.Country_ID], Length (number), Height (number), Speed (text), Opened (text), Status (text))\nTable: country (Country_ID (number) [PK] [FK -> roller_coaster.Country_ID], Name (text), Population (number), Area (number), Languages (text))',
#  'driving_school': 'Table: Addresses (address_id (number) [PK] [FK -> Staff.staff_address_id], line_1_number_building (text), city (text), zip_postcode (text), state_province_county (text), country (text))\nTable: Staff (staff_id (number) [PK] [FK -> Lessons.staff_id], staff_address_id (number) [FK -> Addresses.address_id], nickname (text), first_name (text), middle_name (text), last_name (text), date_of_birth (time), date_joined_staff (time), date_left_staff (time))\nTable: Vehicles (vehicle_id (number) [PK] [FK -> Lessons.vehicle_id], vehicle_details (text))\nTable: Customers (customer_id (number) [PK] [FK -> Customer_Payments.customer_id], customer_address_id (number) [FK -> Addresses.address_id], customer_status_code (text), date_became_customer (time), date_of_birth (time), first_name (text), last_name (text), amount_outstanding (number), email_address (text), phone_number (text), cell_mobile_phone_number (text))\nTable: Customer_Payments (customer_id (number) [PK] [FK -> Customers.customer_id], datetime_payment (time), payment_method_code (text), amount_payment (number))\nTable: Lessons (lesson_id (number) [PK], customer_id (number) [FK -> Customers.customer_id], lesson_status_code (text), staff_id (number) [FK -> Staff.staff_id], vehicle_id (number) [FK -> Vehicles.vehicle_id], lesson_date (time), lesson_time (text), price (number))',
#  'cre_Docs_and_Epenses': 'Table: Ref_Document_Types (Document_Type_Code (text) [PK] [FK -> Documents.Document_Type_Code], Document_Type_Name (text), Document_Type_Description (text))\nTable: Ref_Budget_Codes (Budget_Type_Code (text) [PK] [FK -> Documents_with_Expenses.Budget_Type_Code], Budget_Type_Description (text))\nTable: Projects (Project_ID (number) [PK] [FK -> Documents.Project_ID], Project_Details (text))\nTable: Documents (Document_ID (number) [PK] [FK -> Statements.Statement_ID], Document_Type_Code (text) [FK -> Ref_Document_Types.Document_Type_Code], Project_ID (number) [FK -> Projects.Project_ID], Document_Date (time), Document_Name (text), Document_Description (text), Other_Details (text))\nTable: Statements (Statement_ID (number) [PK] [FK -> Documents.Document_ID], Statement_Details (text))\nTable: Documents_with_Expenses (Document_ID (number) [PK] [FK -> Documents.Document_ID], Budget_Type_Code (text) [FK -> Ref_Budget_Codes.Budget_Type_Code], Document_Details (text))\nTable: Accounts (Account_ID (number) [PK], Statement_ID (number) [FK -> Statements.Statement_ID], Account_Details (text))',
#  'baseball_1': 'Table: all_star (player_id (text) [FK -> player.player_id], year (number), game_num (number), game_id (text), team_id (text), league_id (text), gp (number), starting_pos (number))\nTable: appearances (year (number), team_id (text) [FK -> team.team_id], league_id (text), player_id (text) [FK -> player.player_id], g_all (number), gs (number), g_batting (number), g_defense (number), g_p (number), g_c (number), g_1b (number), g_2b (number), g_3b (number), g_ss (number), g_lf (number), g_cf (number), g_rf (number), g_of (number), g_dh (number), g_ph (number), g_pr (number))\nTable: manager_award (player_id (text) [FK -> player.player_id], award_id (text), year (number), league_id (text), tie (text), notes (number))\nTable: player_award (player_id (text) [FK -> player.player_id], award_id (text), year (number), league_id (text), tie (text), notes (text))\nTable: manager_award_vote (award_id (text), year (number), league_id (text), player_id (text), points_won (number), points_max (number), votes_first (number))\nTable: player_award_vote (award_id (text), year (number), league_id (text), player_id (text) [FK -> player.player_id], points_won (number), points_max (number), votes_first (number))\nTable: batting (player_id (text) [FK -> player.player_id], year (number), stint (number), team_id (text), league_id (text), g (number), ab (number), r (number), h (number), double (number), triple (number), hr (number), rbi (number), sb (number), cs (number), bb (number), so (number), ibb (number), hbp (number), sh (number), sf (number), g_idp (number))\nTable: batting_postseason (year (number), round (text), player_id (text) [FK -> player.player_id], team_id (text) [FK -> team.team_id], league_id (text), g (number), ab (number), r (number), h (number), double (number), triple (number), hr (number), rbi (number), sb (number), cs (number), bb (number), so (number), ibb (number), hbp (number), sh (number), sf (number), g_idp (number))\nTable: player_college (player_id (text) [FK -> player.player_id], college_id (text) [FK -> college.college_id], year (number))\nTable: fielding (player_id (text) [FK -> player.player_id], year (number), stint (number), team_id (text), league_id (text), pos (text), g (number), gs (number), inn_outs (number), po (number), a (number), e (number), dp (number), pb (number), wp (number), sb (number), cs (number), zr (number))\nTable: fielding_outfield (player_id (text) [FK -> player.player_id], year (number), stint (number), glf (number), gcf (number), grf (number))\nTable: fielding_postseason (player_id (text) [FK -> player.player_id], year (number), team_id (text), league_id (text), round (text), pos (text), g (number), gs (number), inn_outs (number), po (number), a (number), e (number), dp (number), tp (number), pb (number), sb (number), cs (number))\nTable: hall_of_fame (player_id (text) [FK -> player.player_id], yearid (number), votedby (text), ballots (number), needed (number), votes (number), inducted (text), category (text), needed_note (text))\nTable: home_game (year (number), league_id (text), team_id (text) [FK -> team.team_id], park_id (text) [FK -> park.park_id], span_first (text), span_last (text), games (number), openings (number), attendance (number))\nTable: manager (player_id (text), year (number), team_id (text) [FK -> team.team_id], league_id (text), inseason (number), g (number), w (number), l (number), rank (number), plyr_mgr (text))\nTable: manager_half (player_id (text), year (number), team_id (text) [FK -> team.team_id], league_id (text), inseason (number), half (number), g (number), w (number), l (number), rank (number))\nTable: player (player_id (text) [FK -> all_star.player_id], birth_year (number), birth_month (number), birth_day (number), birth_country (text), birth_state (text), birth_city (text), death_year (number), death_month (number), death_day (number), death_country (text), death_state (text), death_city (text), name_first (text), name_last (text), name_given (text),  ...
#  'company_office': 'Table: buildings (id (number) [PK] [FK -> Office_locations.building_id], name (text), City (text), Height (number), Stories (number), Status (text))\nTable: Companies (id (number) [PK] [FK -> Office_locations.company_id], name (text), Headquarters (text), Industry (text), Sales_billion (number), Profits_billion (number), Assets_billion (number), Market_Value_billion (text))\nTable: Office_locations (building_id (number) [PK] [FK -> buildings.id], company_id (number) [FK -> Companies.id], move_in_year (number))',
#  'match_season': 'Table: country (Country_id (number) [PK] [FK -> match_season.Country], Country_name (text), Capital (text), Official_native_language (text))\nTable: team (Team_id (number) [PK] [FK -> match_season.Team], Name (text))\nTable: match_season (Season (number) [PK], Player (text), Position (text), Country (number) [FK -> country.Country_id], Team (number) [FK -> team.Team_id], Draft_Pick_Number (number), Draft_Class (text), College (text))\nTable: player (Player_ID (number) [PK], Player (text), Years_Played (text), Total_WL (text), Singles_WL (text), Doubles_WL (text), Team (number) [FK -> team.Team_id])',
#  'workshop_paper': 'Table: workshop (Workshop_ID (number) [PK] [FK -> Acceptance.Workshop_ID], Date (text), Venue (text), Name (text))\nTable: submission (Submission_ID (number) [PK] [FK -> Acceptance.Submission_ID], Scores (number), Author (text), College (text))\nTable: Acceptance (Submission_ID (number) [PK] [FK -> submission.Submission_ID], Workshop_ID (number) [FK -> workshop.Workshop_ID], Result (text))',
#  'protein_institute': 'Table: building (building_id (text) [PK] [FK -> Institution.building_id], Name (text), Street_address (text), Years_as_tallest (text), Height_feet (number), Floors (number))\nTable: Institution (Institution_id (text) [PK] [FK -> protein.Institution_id], Institution (text), Location (text), Founded (number), Type (text), Enrollment (number), Team (text), Primary_Conference (text), building_id (text) [FK -> building.building_id])\nTable: protein (common_name (text) [PK], protein_name (text), divergence_from_human_lineage (number), accession_number (text), sequence_length (number), sequence_identity_to_human_protein (text), Institution_id (text) [FK -> Institution.Institution_id])',
#  'dorm_1': 'Table: Student (StuID (number) [PK] [FK -> Lives_in.stuid], LName (text), Fname (text), Age (number), Sex (text), Major (number), Advisor (number), city_code (text))\nTable: Dorm (dormid (number) [FK -> Has_amenity.dormid], dorm_name (text), student_capacity (number), gender (text))\nTable: Dorm_amenity (amenid (number) [FK -> Has_amenity.amenid], amenity_name (text))\nTable: Has_amenity (dormid (number) [FK -> Dorm.dormid], amenid (number) [FK -> Dorm_amenity.amenid])\nTable: Lives_in (stuid (number) [FK -> Student.StuID], dormid (number) [FK -> Dorm.dormid], room_number (number))',
#  'gymnast': 'Table: gymnast (Gymnast_ID (number) [PK] [FK -> people.People_ID], Floor_Exercise_Points (number), Pommel_Horse_Points (number), Rings_Points (number), Vault_Points (number), Parallel_Bars_Points (number), Horizontal_Bar_Points (number), Total_Points (number))\nTable: people (People_ID (number) [PK] [FK -> gymnast.Gymnast_ID], Name (text), Age (number), Height (number), Hometown (text))',
#  'phone_market': 'Table: phone (Name (text), Phone_ID (number) [PK] [FK -> phone_market.Phone_ID], Memory_in_G (number), Carrier (text), Price (number))\nTable: market (Market_ID (number) [PK] [FK -> phone_market.Market_ID], District (text), Num_of_employees (number), Num_of_shops (number), Ranking (number))\nTable: phone_market (Market_ID (number) [PK] [FK -> market.Market_ID], Phone_ID (text) [FK -> phone.Phone_ID], Num_of_stock (number))',
#  'product_catalog': 'Table: Attribute_Definitions (attribute_id (number) [PK], attribute_name (text), attribute_data_type (text))\nTable: Catalogs (catalog_id (number) [PK] [FK -> Catalog_Structure.catalog_id], catalog_name (text), catalog_publisher (text), date_of_publication (time), date_of_latest_revision (time))\nTable: Catalog_Structure (catalog_level_number (number) [PK] [FK -> Catalog_Contents.catalog_level_number], catalog_id (number) [FK -> Catalogs.catalog_id], catalog_level_name (text))\nTable: Catalog_Contents (catalog_entry_id (number) [PK] [FK -> Catalog_Contents_Additional_Attributes.catalog_entry_id], catalog_level_number (number) [FK -> Catalog_Structure.catalog_level_number], parent_entry_id (number), previous_entry_id (number), next_entry_id (number), catalog_entry_name (text), product_stock_number (text), price_in_dollars (number), price_in_euros (number), price_in_pounds (number), capacity (text), length (text), height (text), width (text))\nTable: Catalog_Contents_Additional_Attributes (catalog_entry_id (number) [FK -> Catalog_Contents.catalog_entry_id], catalog_level_number (number) [FK -> Catalog_Structure.catalog_level_number], attribute_id (number), attribute_value (text))',
#  'bike_1': 'Table: station (id (number) [PK] [FK -> status.station_id], name (text), lat (number), long (number), dock_count (number), city (text), installation_date (text))\nTable: status (station_id (number) [FK -> station.id], bikes_available (number), docks_available (number), time (text))\nTable: trip (id (number) [PK], duration (number), start_date (text), start_station_name (text), start_station_id (number), end_date (text), end_station_name (text), end_station_id (number), bike_id (number), subscription_type (text), zip_code (number))\nTable: weather (date (text), max_temperature_f (number), mean_temperature_f (number), min_temperature_f (number), max_dew_point_f (number), mean_dew_point_f (number), min_dew_point_f (number), max_humidity (number), mean_humidity (number), min_humidity (number), max_sea_level_pressure_inches (number), mean_sea_level_pressure_inches (number), min_sea_level_pressure_inches (number), max_visibility_miles (number), mean_visibility_miles (number), min_visibility_miles (number), max_wind_Speed_mph (number), mean_wind_speed_mph (number), max_gust_speed_mph (number), precipitation_inches (number), cloud_cover (number), events (text), wind_dir_degrees (number), zip_code (number))',
#  'employee_hire_evaluation': 'Table: employee (Employee_ID (number) [PK] [FK -> hiring.Employee_ID], Name (text), Age (number), City (text))\nTable: shop (Shop_ID (number) [PK] [FK -> hiring.Shop_ID], Name (text), Location (text), District (text), Number_products (number), Manager_name (text))\nTable: hiring (Shop_ID (number) [FK -> shop.Shop_ID], Employee_ID (number) [PK] [FK -> employee.Employee_ID], Start_from (text), Is_full_time (others))\nTable: evaluation (Employee_ID (text) [PK] [FK -> employee.Employee_ID], Year_awarded (text), Bonus (number))',
#  'body_builder': 'Table: body_builder (Body_Builder_ID (number) [PK], People_ID (number) [FK -> people.People_ID], Snatch (number), Clean_Jerk (number), Total (number))\nTable: people (People_ID (number) [PK] [FK -> body_builder.People_ID], Name (text), Height (number), Weight (number), Birth_Date (text), Birth_Place (text))',
#  'museum_visit': 'Table: museum (Museum_ID (number) [PK] [FK -> visit.Museum_ID], Name (text), Num_of_Staff (number), Open_Year (text))\nTable: visitor (ID (number) [PK] [FK -> visit.visitor_ID], Name (text), Level_of_membership (number), Age (number))\nTable: visit (Museum_ID (number) [PK] [FK -> museum.Museum_ID], visitor_ID (text) [FK -> visitor.ID], Num_of_Ticket (number), Total_spent (number))',
#  'cre_Doc_Template_Mgt': 'Table: Ref_Template_Types (Template_Type_Code (text) [PK] [FK -> Templates.Template_Type_Code], Template_Type_Description (text))\nTable: Templates (Template_ID (number) [PK] [FK -> Documents.Template_ID], Version_Number (number), Template_Type_Code (text) [FK -> Ref_Template_Types.Template_Type_Code], Date_Effective_From (time), Date_Effective_To (time), Template_Details (text))\nTable: Documents (Document_ID (number) [PK] [FK -> Paragraphs.Document_ID], Template_ID (number) [FK -> Templates.Template_ID], Document_Name (text), Document_Description (text), Other_Details (text))\nTable: Paragraphs (Paragraph_ID (number) [PK], Document_ID (number) [FK -> Documents.Document_ID], Paragraph_Text (text), Other_Details (text))',
#  'student_1': 'Table: list (LastName (text) [PK], FirstName (text), Grade (number), Classroom (number))\nTable: teachers (LastName (text) [PK], FirstName (text), Classroom (number))',
#  'local_govt_mdm': 'Table: Customer_Master_Index (master_customer_id (number) [PK] [FK -> CMI_Cross_References.master_customer_id], cmi_details (text))\nTable: CMI_Cross_References (cmi_cross_ref_id (number) [PK] [FK -> Council_Tax.cmi_cross_ref_id], master_customer_id (number) [FK -> Customer_Master_Index.master_customer_id], source_system_code (text))\nTable: Council_Tax (council_tax_id (number) [PK], cmi_cross_ref_id (number) [FK -> CMI_Cross_References.cmi_cross_ref_id])\nTable: Business_Rates (business_rates_id (number) [PK], cmi_cross_ref_id (number) [FK -> CMI_Cross_References.cmi_cross_ref_id])\nTable: Benefits_Overpayments (council_tax_id (number) [PK], cmi_cross_ref_id (number) [FK -> CMI_Cross_References.cmi_cross_ref_id])\nTable: Parking_Fines (council_tax_id (number) [PK], cmi_cross_ref_id (number) [FK -> CMI_Cross_References.cmi_cross_ref_id])\nTable: Rent_Arrears (council_tax_id (number) [PK], cmi_cross_ref_id (number) [FK -> CMI_Cross_References.cmi_cross_ref_id])\nTable: Electoral_Register (electoral_register_id (number) [PK], cmi_cross_ref_id (number) [FK -> CMI_Cross_References.cmi_cross_ref_id])',
#  'company_employee': 'Table: people (People_ID (number) [PK] [FK -> employment.People_ID], Age (number), Name (text), Nationality (text), Graduation_College (text))\nTable: company (Company_ID (number) [PK] [FK -> employment.Company_ID], Name (text), Headquarters (text), Industry (text), Sales_in_Billion (number), Profits_in_Billion (number), Assets_in_Billion (number), Market_Value_in_Billion (number))\nTable: employment (Company_ID (number) [PK] [FK -> company.Company_ID], People_ID (number) [FK -> people.People_ID], Year_working (number))',
#  'sports_competition': 'Table: club (Club_ID (number) [PK] [FK -> club_rank.Club_ID], name (text), Region (text), Start_year (text))\nTable: club_rank (Rank (number) [PK], Club_ID (number) [FK -> club.Club_ID], Gold (number), Silver (number), Bronze (number), Total (number))\nTable: player (Player_ID (number) [PK], name (text), Position (text), Club_ID (number) [FK -> club.Club_ID], Apps (number), Tries (number), Goals (text), Points (number))\nTable: competition (Competition_ID (number) [PK] [FK -> competition_result.Competition_ID], Year (number), Competition_type (text), Country (text))\nTable: competition_result (Competition_ID (number) [PK] [FK -> competition.Competition_ID], Club_ID_1 (number) [FK -> club.Club_ID], Club_ID_2 (number) [FK -> club.Club_ID], Score (text))',
#  'browser_web': 'Table: Web_client_accelerator (id (number) [PK] [FK -> accelerator_compatible_browser.accelerator_id], name (text), Operating_system (text), Client (text), Connection (text))\nTable: browser (id (number) [PK] [FK -> accelerator_compatible_browser.browser_id], name (text), market_share (number))\nTable: accelerator_compatible_browser (accelerator_id (number) [PK] [FK -> Web_client_accelerator.id], browser_id (number) [FK -> browser.id], compatible_since_year (number))',
#  'election_representative': 'Table: election (Election_ID (number) [PK], Representative_ID (number) [FK -> representative.Representative_ID], Date (text), Votes (number), Vote_Percent (number), Seats (number), Place (number))\nTable: representative (Representative_ID (number) [PK] [FK -> election.Representative_ID], Name (text), State (text), Party (text), Lifespan (text))',
#  'course_teach': 'Table: course (Course_ID (number) [PK] [FK -> course_arrange.Course_ID], Staring_Date (text), Course (text))\nTable: teacher (Teacher_ID (number) [PK] [FK -> course_arrange.Teacher_ID], Name (text), Age (text), Hometown (text))\nTable: course_arrange (Course_ID (number) [PK] [FK -> course.Course_ID], Teacher_ID (number) [FK -> teacher.Teacher_ID], Grade (number))',
#  'pets_1': 'Table: Student (StuID (number) [PK] [FK -> Has_Pet.StuID], LName (text), Fname (text), Age (number), Sex (text), Major (number), Advisor (number), city_code (text))\nTable: Has_Pet (StuID (number) [FK -> Student.StuID], PetID (number) [FK -> Pets.PetID])\nTable: Pets (PetID (number) [PK] [FK -> Has_Pet.PetID], PetType (text), pet_age (number), weight (number))',
#  'club_1': 'Table: Student (StuID (number) [PK] [FK -> Member_of_club.StuID], LName (text), Fname (text), Age (number), Sex (text), Major (number), Advisor (number), city_code (text))\nTable: Club (ClubID (number) [PK] [FK -> Member_of_club.ClubID], ClubName (text), ClubDesc (text), ClubLocation (text))\nTable: Member_of_club (StuID (number) [FK -> Student.StuID], ClubID (number) [FK -> Club.ClubID], Position (text))',
#  'yelp': 'Table: business (bid (number) [PK], business_id (text) [FK -> category.business_id], name (text), full_address (text), city (text), latitude (text), longitude (text), review_count (number), is_open (number), rating (number), state (text))\nTable: category (id (number) [PK], business_id (text) [FK -> business.business_id], category_name (text))\nTable: user (uid (number) [PK], user_id (text) [FK -> review.user_id], name (text))\nTable: checkin (cid (number) [PK], business_id (text) [FK -> business.business_id], count (number), day (text))\nTable: neighbourhood (id (number) [PK], business_id (text) [FK -> business.business_id], neighbourhood_name (text))\nTable: review (rid (number) [PK], business_id (text) [FK -> business.business_id], user_id (text) [FK -> user.user_id], rating (number), text (text), year (number), month (text))\nTable: tip (tip_id (number) [PK], business_id (text) [FK -> business.business_id], text (text), user_id (text) [FK -> user.user_id], likes (number), year (number), month (text))',
# ...
#  'medicine_enzyme_interaction': 'Table: medicine (id (number) [PK] [FK -> medicine_enzyme_interaction.medicine_id], name (text), Trade_Name (text), FDA_approved (text))\nTable: enzyme (id (number) [PK] [FK -> medicine_enzyme_interaction.enzyme_id], name (text), Location (text), Product (text), Chromosome (text), OMIM (number), Porphyria (text))\nTable: medicine_enzyme_interaction (enzyme_id (number) [PK] [FK -> enzyme.id], medicine_id (number) [FK -> medicine.id], interaction_type (text))',
#  'school_player': 'Table: school (School_ID (number) [PK] [FK -> school_details.School_ID], School (text), Location (text), Enrollment (number), Founded (number), Denomination (text), Boys_or_Girls (text), Day_or_Boarding (text), Year_Entered_Competition (number), School_Colors (text))\nTable: school_details (School_ID (number) [PK] [FK -> school.School_ID], Nickname (text), Colors (text), League (text), Class (text), Division (text))\nTable: school_performance (School_Id (number) [PK] [FK -> school.School_ID], School_Year (text), Class_A (text), Class_AA (text))\nTable: player (Player_ID (number) [PK], Player (text), Team (text), Age (number), Position (text), School_ID (number) [FK -> school.School_ID])',
#  'tvshow': 'Table: TV_Channel (id (text) [PK] [FK -> TV_series.Channel], series_name (text), Country (text), Language (text), Content (text), Pixel_aspect_ratio_PAR (text), Hight_definition_TV (text), Pay_per_view_PPV (text), Package_Option (text))\nTable: TV_series (id (number) [PK], Episode (text), Air_Date (text), Rating (text), Share (number), 18_49_Rating_Share (text), Viewers_m (text), Weekly_Rank (number), Channel (text) [FK -> TV_Channel.id])\nTable: Cartoon (id (number) [PK], Title (text), Directed_by (text), Written_by (text), Original_air_date (text), Production_code (number), Channel (text) [FK -> TV_Channel.id])',
#  'products_gen_characteristics': 'Table: Ref_Characteristic_Types (characteristic_type_code (text) [PK] [FK -> Characteristics.characteristic_type_code], characteristic_type_description (text))\nTable: Ref_Colors (color_code (text) [PK] [FK -> Products.color_code], color_description (text))\nTable: Ref_Product_Categories (product_category_code (text) [PK] [FK -> Products.product_category_code], product_category_description (text), unit_of_measure (text))\nTable: Characteristics (characteristic_id (number) [PK] [FK -> Product_Characteristics.characteristic_id], characteristic_type_code (text) [FK -> Ref_Characteristic_Types.characteristic_type_code], characteristic_data_type (text), characteristic_name (text), other_characteristic_details (text))\nTable: Products (product_id (number) [PK] [FK -> Product_Characteristics.product_id], color_code (text) [FK -> Ref_Colors.color_code], product_category_code (text) [FK -> Ref_Product_Categories.product_category_code], product_name (text), typical_buying_price (text), typical_selling_price (text), product_description (text), other_product_details (text))\nTable: Product_Characteristics (product_id (number) [FK -> Products.product_id], characteristic_id (number) [FK -> Characteristics.characteristic_id], product_characteristic_value (text))',
#  'aircraft': 'Table: pilot (Pilot_Id (number) [PK] [FK -> match.Winning_Pilot], Name (text), Age (number))\nTable: aircraft (Aircraft_ID (number) [PK] [FK -> match.Winning_Aircraft], Aircraft (text), Description (text), Max_Gross_Weight (text), Total_disk_area (text), Max_disk_Loading (text))\nTable: match (Round (number) [PK], Location (text), Country (text), Date (text), Fastest_Qualifying (text), Winning_Pilot (text) [FK -> pilot.Pilot_Id], Winning_Aircraft (text) [FK -> aircraft.Aircraft_ID])\nTable: airport (Airport_ID (number) [PK] [FK -> airport_aircraft.Airport_ID], Airport_Name (text), Total_Passengers (number), %_Change_2007 (text), International_Passengers (number), Domestic_Passengers (number), Transit_Passengers (number), Aircraft_Movements (number), Freight_Metric_Tonnes (number))\nTable: airport_aircraft (ID (number), Airport_ID (number) [PK] [FK -> airport.Airport_ID], Aircraft_ID (number) [FK -> aircraft.Aircraft_ID])',
#  'cre_Drama_Workshop_Groups': 'Table: Ref_Payment_Methods (payment_method_code (text) [PK] [FK -> Invoices.payment_method_code], payment_method_description (text))\nTable: Ref_Service_Types (Service_Type_Code (text) [PK] [FK -> Services.Service_Type_Code], Parent_Service_Type_Code (text), Service_Type_Description (text))\nTable: Addresses (Address_ID (text) [PK] [FK -> Clients.Address_ID], Line_1 (text), Line_2 (text), City_Town (text), State_County (text), Other_Details (text))\nTable: Products (Product_ID (text) [PK] [FK -> Order_Items.Product_ID], Product_Name (text), Product_Price (number), Product_Description (text), Other_Product_Service_Details (text))\nTable: Marketing_Regions (Marketing_Region_Code (text) [PK] [FK -> Stores.Marketing_Region_Code], Marketing_Region_Name (text), Marketing_Region_Descriptrion (text), Other_Details (text))\nTable: Clients (Client_ID (number) [PK] [FK -> Bookings.Customer_ID], Address_ID (number) [FK -> Addresses.Address_ID], Customer_Email_Address (text), Customer_Name (text), Customer_Phone (text), Other_Details (text))\nTable: Drama_Workshop_Groups (Workshop_Group_ID (number) [PK] [FK -> Bookings.Workshop_Group_ID], Address_ID (number) [FK -> Addresses.Address_ID], Currency_Code (text), Marketing_Region_Code (text), Store_Name (text), Store_Phone (text), Store_Email_Address (text), Other_Details (text))\nTable: Performers (Performer_ID (number) [PK] [FK -> Performers_in_Bookings.Performer_ID], Address_ID (number) [FK -> Addresses.Address_ID], Customer_Name (text), Customer_Phone (text), Customer_Email_Address (text), Other_Details (text))\nTable: Customers (Customer_ID (text) [PK] [FK -> Customer_Orders.Customer_ID], Address_ID (number) [FK -> Addresses.Address_ID], Customer_Name (text), Customer_Phone (text), Customer_Email_Address (text), Other_Details (text))\nTable: Stores (Store_ID (text) [PK] [FK -> Customer_Orders.Store_ID], Address_ID (number) [FK -> Addresses.Address_ID], Marketing_Region_Code (text) [FK -> Marketing_Regions.Marketing_Region_Code], Store_Name (text), Store_Phone (text), Store_Email_Address (text), Other_Details (text))\nTable: Bookings (Booking_ID (number) [PK] [FK -> Performers_in_Bookings.Order_ID], Customer_ID (number) [FK -> Clients.Client_ID], Workshop_Group_ID (text) [FK -> Drama_Workshop_Groups.Workshop_Group_ID], Status_Code (text), Store_ID (number), Order_Date (time), Planned_Delivery_Date (time), Actual_Delivery_Date (time), Other_Order_Details (text))\nTable: Performers_in_Bookings (Order_ID (number) [PK] [FK -> Bookings.Booking_ID], Performer_ID (number) [FK -> Performers.Performer_ID])\nTable: Customer_Orders (Order_ID (number) [PK] [FK -> Order_Items.Order_ID], Customer_ID (number) [FK -> Customers.Customer_ID], Store_ID (number) [FK -> Stores.Store_ID], Order_Date (time), Planned_Delivery_Date (time), Actual_Delivery_Date (time), Other_Order_Details (text))\nTable: Order_Items (Order_Item_ID (number) [PK] [FK -> Invoice_Items.Order_Item_ID], Order_ID (number) [FK -> Customer_Orders.Order_ID], Product_ID (number) [FK -> Products.Product_ID], Order_Quantity (text), Other_Item_Details (text))\nTable: Invoices (Invoice_ID (number) [PK] [FK -> Invoice_Items.Invoice_ID], Order_ID (number) [FK -> Bookings.Booking_ID], payment_method_code (text) [FK -> Ref_Payment_Methods.payment_method_code], Product_ID (number), Order_Quantity (text), Other_Item_Details (text), Order_Item_ID (number))\nTable: Services (Service_ID (number) [PK] [FK -> Bookings_Services.Product_ID], Service_Type_Code (text) [FK -> Ref_Service_Types.Service_Type_Code], Workshop_Group_ID (number) [FK -> Drama_Workshop_Groups.Workshop_Group_ID], Product_Description (text), Product_Name (text), Product_Price (number), Other_Product_Service_Details (text))\nTable: Bookings_Services (Order_ID (number) [PK] [FK -> Bookings.Booking_ID], Product_ID (number) [FK -> Services.Service_ID])\nTable: Invoice_Items (Invoice_Item_ID (number) [PK], Invoice_ID (number) [FK -> Invoices.Invoice_ID], Order_ID ...
#  'game_injury': 'Table: stadium (id (number) [PK] [FK -> game.stadium_id], name (text), Home_Games (number), Average_Attendance (number), Total_Attendance (number), Capacity_Percentage (number))\nTable: game (stadium_id (number) [FK -> stadium.id], id (number) [PK] [FK -> injury_accident.game_id], Season (number), Date (text), Home_team (text), Away_team (text), Score (text), Competition (text))\nTable: injury_accident (game_id (number) [FK -> game.id], id (number) [PK], Player (text), Injury (text), Number_of_matches (text), Source (text))',
#  'car_1': 'Table: continents (ContId (number) [PK] [FK -> countries.Continent], Continent (text))\nTable: countries (CountryId (number) [PK] [FK -> car_makers.Country], CountryName (text), Continent (number) [FK -> continents.ContId])\nTable: car_makers (Id (number) [PK] [FK -> model_list.Maker], Maker (text), FullName (text), Country (text) [FK -> countries.CountryId])\nTable: model_list (ModelId (number) [PK], Maker (number) [FK -> car_makers.Id], Model (text) [FK -> car_names.Model])\nTable: car_names (MakeId (number) [PK] [FK -> cars_data.Id], Model (text) [FK -> model_list.Model], Make (text))\nTable: cars_data (Id (number) [PK] [FK -> car_names.MakeId], MPG (text), Cylinders (number), Edispl (number), Horsepower (text), Weight (number), Accelerate (number), Year (number))',
#  'activity_1': 'Table: Activity (actid (number) [PK] [FK -> Participates_in.actid], activity_name (text))\nTable: Participates_in (stuid (number) [FK -> Student.StuID], actid (number) [FK -> Activity.actid])\nTable: Faculty_Participates_in (FacID (number) [FK -> Faculty.FacID], actid (number) [FK -> Activity.actid])\nTable: Student (StuID (number) [PK] [FK -> Participates_in.stuid], LName (text), Fname (text), Age (number), Sex (text), Major (number), Advisor (number), city_code (text))\nTable: Faculty (FacID (number) [PK] [FK -> Faculty_Participates_in.FacID], Lname (text), Fname (text), Rank (text), Sex (text), Phone (number), Room (text), Building (text))',
#  'film_rank': 'Table: film (Film_ID (number) [PK] [FK -> film_market_estimation.Film_ID], Title (text), Studio (text), Director (text), Gross_in_dollar (number))\nTable: market (Market_ID (number) [PK] [FK -> film_market_estimation.Market_ID], Country (text), Number_cities (number))\nTable: film_market_estimation (Estimation_ID (number) [PK], Low_Estimate (number), High_Estimate (number), Film_ID (number) [FK -> film.Film_ID], Type (text), Market_ID (number) [FK -> market.Market_ID], Year (number))',
#  'academic': 'Table: author (aid (number) [PK] [FK -> domain_author.aid], homepage (text), name (text), oid (number))\nTable: conference (cid (number) [PK] [FK -> domain_conference.cid], homepage (text), name (text))\nTable: domain (did (number) [PK] [FK -> domain_author.did], name (text))\nTable: domain_author (aid (number) [FK -> author.aid], did (number) [PK] [FK -> domain.did])\nTable: domain_conference (cid (number) [FK -> conference.cid], did (number) [PK] [FK -> domain.did])\nTable: journal (homepage (text), jid (number) [PK] [FK -> domain_journal.jid], name (text))\nTable: domain_journal (did (number) [PK] [FK -> domain.did], jid (number) [FK -> journal.jid])\nTable: keyword (keyword (text), kid (number) [PK] [FK -> domain_keyword.kid])\nTable: domain_keyword (did (number) [PK] [FK -> domain.did], kid (number) [FK -> keyword.kid])\nTable: publication (abstract (text), cid (text) [FK -> conference.cid], citation_num (number), jid (number) [FK -> journal.jid], pid (number) [PK] [FK -> domain_publication.pid], reference_num (number), title (text), year (number))\nTable: domain_publication (did (number) [PK] [FK -> domain.did], pid (number) [FK -> publication.pid])\nTable: organization (continent (text), homepage (text), name (text), oid (number) [PK])\nTable: publication_keyword (pid (number) [FK -> publication.pid], kid (number) [PK] [FK -> keyword.kid])\nTable: writes (aid (number) [PK] [FK -> author.aid], pid (number) [FK -> publication.pid])\nTable: cite (cited (number) [FK -> publication.pid], citing (number) [FK -> publication.pid])',
#  'pilot_record': 'Table: aircraft (Aircraft_ID (number) [PK] [FK -> pilot_record.Aircraft_ID], Order_Year (number), Manufacturer (text), Model (text), Fleet_Series (text), Powertrain (text), Fuel_Propulsion (text))\nTable: pilot (Pilot_ID (number) [PK] [FK -> pilot_record.Pilot_ID], Pilot_name (text), Rank (number), Age (number), Nationality (text), Position (text), Join_Year (number), Team (text))\nTable: pilot_record (Record_ID (number), Pilot_ID (number) [PK] [FK -> pilot.Pilot_ID], Aircraft_ID (number) [FK -> aircraft.Aircraft_ID], Date (text))',
#  'wedding': 'Table: people (People_ID (number) [PK] [FK -> wedding.Female_ID], Name (text), Country (text), Is_Male (text), Age (number))\nTable: church (Church_ID (number) [PK] [FK -> wedding.Church_ID], Name (text), Organized_by (text), Open_Date (number), Continuation_of (text))\nTable: wedding (Church_ID (number) [PK] [FK -> church.Church_ID], Male_ID (number) [FK -> people.People_ID], Female_ID (number) [FK -> people.People_ID], Year (number))',
#  'customers_card_transactions': 'Table: Accounts (account_id (number) [PK] [FK -> Financial_Transactions.account_id], customer_id (number), account_name (text), other_account_details (text))\nTable: Customers (customer_id (number) [PK], customer_first_name (text), customer_last_name (text), customer_address (text), customer_phone (text), customer_email (text), other_customer_details (text))\nTable: Customers_Cards (card_id (number) [PK] [FK -> Financial_Transactions.card_id], customer_id (number), card_type_code (text), card_number (text), date_valid_from (time), date_valid_to (time), other_card_details (text))\nTable: Financial_Transactions (transaction_id (number), previous_transaction_id (number), account_id (number) [FK -> Accounts.account_id], card_id (number) [FK -> Customers_Cards.card_id], transaction_type (text), transaction_date (time), transaction_amount (number), transaction_comment (text), other_transaction_details (text))',
#  'imdb': 'Table: actor (aid (number) [PK] [FK -> cast.aid], gender (text), name (text), nationality (text), birth_city (text), birth_year (number))\nTable: copyright (id (number) [PK], msid (number) [FK -> cast.msid], cid (number))\nTable: cast (id (number) [PK], msid (number) [FK -> copyright.msid], aid (number) [FK -> actor.aid], role (number))\nTable: genre (gid (number) [PK] [FK -> classification.gid], genre (text))\nTable: classification (id (number) [PK], msid (number) [FK -> copyright.msid], gid (number) [FK -> genre.gid])\nTable: company (id (number) [PK], name (text), country_code (text))\nTable: director (did (number) [PK] [FK -> directed_by.did], gender (text), name (text), nationality (text), birth_city (text), birth_year (number))\nTable: producer (pid (number) [PK] [FK -> made_by.pid], gender (text), name (text), nationality (text), birth_city (text), birth_year (number))\nTable: directed_by (id (number) [PK], msid (number) [FK -> copyright.msid], did (number) [FK -> director.did])\nTable: keyword (id (number) [PK], keyword (text))\nTable: made_by (id (number) [PK], msid (number) [FK -> copyright.msid], pid (number) [FK -> producer.pid])\nTable: movie (mid (number) [PK], title (text), release_year (number), title_aka (text), budget (text))\nTable: tags (id (number) [PK], msid (number) [FK -> copyright.msid], kid (number))\nTable: tv_series (sid (number) [PK], title (text), release_year (number), num_of_seasons (number), num_of_episodes (number), title_aka (text), budget (text))\nTable: writer (wid (number) [PK] [FK -> written_by.wid], gender (text), name (number), nationality (number), num_of_episodes (number), birth_city (text), birth_year (number))\nTable: written_by (id (number), msid (number) [FK -> copyright.msid], wid (number) [FK -> writer.wid])'}

# %%
training_text_schema = {}
training_struct_schema = {}

dataset_dir = os.path.join(spider_dir, "database")
db_dirs = [d for d in os.listdir(dataset_dir) if os.path.isdir(os.path.join(dataset_dir, d))]

for db in db_dirs:
    if db in text_schema_dict:
        training_text_schema.update({db: text_schema_dict[db]})
        training_struct_schema.update({db: struct_schema_dict[db]})

# %%
print(f"Loaded schema information for {len(training_struct_schema)} databases")
# Out:
# Loaded schema information for 133 databases

# %%
final_training_data = []

for data in training_data:
    if data['db_id'] in training_text_schema.keys():
        final_training_data.append(data)

len(final_training_data)
# Out:
# 6654

# %%
train_examples, temp_examples = train_test_split(
        final_training_data, test_size=0.2, random_state=42)

val_examples, test_examples = train_test_split(
    temp_examples, test_size=0.5, random_state=42)

print(f"Training examples: {len(train_examples)}")
print(f"Validation examples: {len(val_examples)}")
print(f"Test examples: {len(test_examples)}")
# Out:
# Training examples: 5323
# Validation examples: 665
# Test examples: 666

# %%
model_name = "t5-base"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
model.gradient_checkpointing_enable()

# %%
def create_input_text(question, db_id, schema_dict):
    schema = schema_dict[db_id]
    return f"translate to SQL: {question} \n{schema}"

# %%
class SQLDataset(Dataset):
    def __init__(self, examples, schema_dict, tokenizer, max_input_length=512, max_target_length=128):
        self.examples = examples
        self.schema_dict = schema_dict
        self.tokenizer = tokenizer
        self.max_input_length = max_input_length
        self.max_target_length = max_target_length

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, idx):
        ex = self.examples[idx]
        question = ex["question"]
        sql = ex["query"]
        db_id = ex["db_id"]

        input_text = create_input_text(question, db_id, self.schema_dict)

        # Tokenize inputs and outputs
        input_encodings = self.tokenizer(
            input_text,
            max_length=self.max_input_length,
            padding="max_length",
            truncation=True,
            return_tensors="pt"
        )

        target_encodings = self.tokenizer(
            sql,
            max_length=self.max_target_length,
            padding="max_length",
            truncation=True,
            return_tensors="pt"
        )

        # Important: Replace padding token id with -100 so it's ignored in loss calculation
        target_encodings.input_ids[target_encodings.input_ids == self.tokenizer.pad_token_id] = -100

        return {
            'input_ids': input_encodings.input_ids.squeeze(),
            'attention_mask': input_encodings.attention_mask.squeeze(),
            'labels': target_encodings.input_ids.squeeze(),
            'question': question,
            'sql': sql,
            'db_id': db_id
        }

# %%
train_dataset = SQLDataset(train_examples, training_text_schema, tokenizer)
val_dataset = SQLDataset(val_examples, training_text_schema, tokenizer)
test_dataset = SQLDataset(test_examples, training_text_schema, tokenizer)

# %%
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8)
test_loader = DataLoader(test_dataset, batch_size=8)

# %%
optimizer = AdamW(model.parameters(), lr=5e-5)
num_training_steps = len(train_loader) * 5
scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=int(0.1*num_training_steps),
    num_training_steps=num_training_steps
)
scaler = GradScaler()

# %%
def save_checkpoint(checkpoint_dir, model, optimizer, scheduler, scaler, epoch, step,
                   train_losses, val_losses, best_val_loss, is_best=False, is_latest=True):
    checkpoint = {
        'epoch': epoch,
        'step': step,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scheduler_state_dict': scheduler.state_dict(),
        'scaler_state_dict': scaler.state_dict(),
        'train_losses': train_losses,
        'val_losses': val_losses,
        'best_val_loss': best_val_loss
    }

    # latest model checkpoint
    if is_latest:
        torch.save(checkpoint, os.path.join(checkpoint_dir, 'latest_checkpoint.pt'))

    # best model checkpoint
    if is_best:
        torch.save(model.state_dict(), os.path.join(checkpoint_dir, 'best_model.pt'))

# %%
def load_checkpoint(checkpoint_path, model, optimizer, scheduler, scaler):
    if not os.path.exists(checkpoint_path):
        print(f"No checkpoint found at {checkpoint_path}, starting from scratch")
        return 0, 0, [], [], float('inf')

    checkpoint = torch.load(checkpoint_path)

    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    scaler.load_state_dict(checkpoint['scaler_state_dict'])

    epoch = checkpoint['epoch']
    step = checkpoint['step']
    train_losses = checkpoint['train_losses']
    val_losses = checkpoint['val_losses']
    best_val_loss = checkpoint['best_val_loss']

    print(f"Loaded checkpoint from epoch {epoch+1}, step {step+1}")
    print(f"Best validation loss so far: {best_val_loss:.4f}")

    return epoch + 1, step, train_losses, val_losses, best_val_loss

# %%
def plot_training_progress(train_losses, val_losses, checkpoint_dir):
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.savefig(os.path.join(checkpoint_dir, 'training_progress.png'))
    plt.close()

# %%
def train_model(model, train_loader, val_loader, optimizer, scheduler, num_epochs=5,
                gradient_accumulation_steps=4, start_epoch=0, checkpoint_dir=f"{spider_dir}/checkpoints"):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    train_losses = []
    val_losses = []
    best_val_loss = float('inf')

    # Training loop
    for epoch in range(start_epoch, num_epochs):
        model.train()
        total_train_loss = 0

        progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]")
        for step, batch in enumerate(progress_bar):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            # Forward pass with mixed precision
            with autocast(device_type="cuda"):
                outputs = model(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    labels=labels
                )
                loss = outputs.loss / gradient_accumulation_steps

            # Backward pass with gradient scaling
            scaler.scale(loss).backward()

            if (step + 1) % gradient_accumulation_steps == 0:
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                scaler.step(optimizer)
                scaler.update()
                scheduler.step()
                optimizer.zero_grad()

            total_train_loss += loss.item() * gradient_accumulation_steps
            progress_bar.set_postfix({"loss": loss.item() * gradient_accumulation_steps})

            # Save periodic checkpoint (every 1000 steps)
            if (step + 1) % 1000 == 0:
                save_checkpoint(checkpoint_dir, model, optimizer, scheduler, scaler, epoch, step,
                    train_losses, val_losses, best_val_loss, is_best=False, is_latest=True)

        avg_train_loss = total_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        print(f"Average training loss: {avg_train_loss:.4f}")

        # Validation
        model.eval()
        total_val_loss = 0

        with torch.no_grad():
            for batch in tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Val]"):
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)

                outputs = model(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    labels=labels
                )

                loss = outputs.loss
                total_val_loss += loss.item()

        avg_val_loss = total_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        print(f"Average validation loss: {avg_val_loss:.4f}")

        # Check if this is the best model
        is_best = avg_val_loss < best_val_loss
        if is_best:
            best_val_loss = avg_val_loss
            print(f"New best model with validation loss: {best_val_loss:.4f}")

        # Save epoch checkpoint
        save_checkpoint(checkpoint_dir, model, optimizer, scheduler, scaler,epoch, len(train_loader) - 1,
            train_losses, val_losses, best_val_loss, is_best=is_best, is_latest=True)

        # Plot training progress after each epoch
        plot_training_progress(train_losses, val_losses, checkpoint_dir)

    return train_losses, val_losses

# %%
checkpoint_dir = f"{spider_dir}/checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

# %%
start_epoch = 0
train_losses = []
val_losses = []

# %%
checkpoint_path = os.path.join(checkpoint_dir, 'latest_checkpoint.pt')

if os.path.exists(checkpoint_path):

    # Load from checkpoint
    start_epoch, _, train_losses, val_losses, _ = load_checkpoint(
        checkpoint_path, model, optimizer, scheduler, scaler)
else:
    print("No checkpoint found. Starting training from scratch.")
# Out:
# No checkpoint found. Starting training from scratch.

# %%
print(f"Starting model training from epoch {start_epoch+1}...")
train_losses, val_losses = train_model(model=model, train_loader=train_loader, val_loader=val_loader, optimizer=optimizer,
    scheduler=scheduler, num_epochs=5, gradient_accumulation_steps=4, start_epoch=start_epoch, checkpoint_dir=checkpoint_dir)
# Out:
# Starting model training from epoch 1...
# Epoch 1/5 [Train]:   0%|          | 0/666 [00:00<?, ?it/s]
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# Average training loss: 2.5908
# Epoch 1/5 [Val]:   0%|          | 0/84 [00:00<?, ?it/s]
# Average validation loss: 0.8172
# New best model with validation loss: 0.8172
# Epoch 2/5 [Train]:   0%|          | 0/666 [00:00<?, ?it/s]
# Average training loss: 0.7154
# Epoch 2/5 [Val]:   0%|          | 0/84 [00:00<?, ?it/s]
# Average validation loss: 0.4072
# New best model with validation loss: 0.4072
# Epoch 3/5 [Train]:   0%|          | 0/666 [00:00<?, ?it/s]
# Average training loss: 0.4405
# Epoch 3/5 [Val]:   0%|          | 0/84 [00:00<?, ?it/s]
# Average validation loss: 0.2958
# New best model with validation loss: 0.2958
# Epoch 4/5 [Train]:   0%|          | 0/666 [00:00<?, ?it/s]
# Average training loss: 0.3360
# Epoch 4/5 [Val]:   0%|          | 0/84 [00:00<?, ?it/s]
# Average validation loss: 0.2359
# New best model with validation loss: 0.2359
# Epoch 5/5 [Train]:   0%|          | 0/666 [00:00<?, ?it/s]
# Average training loss: 0.2754
# Epoch 5/5 [Val]:   0%|          | 0/84 [00:00<?, ?it/s]
# Average validation loss: 0.2069
# New best model with validation loss: 0.2069

# %%
print("Loading best model for evaluation...")
# best_model_path = os.path.join(checkpoint_dir, 'best_model.pt')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model.load_state_dict(torch.load(best_model_path))
model.to(device)
model.eval()
# Out:
# Loading best model for evaluation...
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=32128, bias=False)
# )

# %%
def normalize_sql(sql):
    sql = re.sub(r'\s+', ' ', sql).strip()
    sql = sql.lower()
    sql = re.sub(r'(=|<|>|<=|>=)', lambda m: f" {m.group(0)} ", sql)
    sql = re.sub(r'\s+', ' ', sql).strip()
    return sql

# %%
def execute_sql(sql, db_path):
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        cursor.execute(sql)
        results = cursor.fetchall()
        conn.close()
        return results
    except Exception as e:
        return str(e)

# %%
def evaluate_model(model, tokenizer, val_dataset, schema_dict, db_dir):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()

    exact_match = 0
    execution_match = 0
    execution_true = 0
    simple_count = 0
    simple_exact_match = 0
    simple_execution_match = 0
    complex_count = 0
    complex_exact_match = 0
    complex_execution_match = 0
    total = len(val_dataset)

    simple_query = True

    for i in tqdm(range(total), desc="Evaluating"):
        example = val_dataset[i]
        question = example['question']
        db_id = example['db_id']
        true_sql = example['sql']

        # Format input
        input_text = create_input_text(question, db_id, schema_dict)

        # Generate SQL
        input_ids = tokenizer(
            input_text,
            max_length=512,
            padding="max_length",
            truncation=True,
            return_tensors="pt"
        ).input_ids.to(device)

        with torch.no_grad():
            outputs = model.generate(
                input_ids=input_ids,
                max_length=128,
                num_beams=5,
                early_stopping=True
            )

        # Decode prediction
        pred_sql = tokenizer.decode(outputs[0], skip_special_tokens=True)

        print("True", true_sql)
        print("Pred", pred_sql)

        # Normalize for comparison
        pred_sql_norm = normalize_sql(pred_sql)
        true_sql_norm = normalize_sql(true_sql)

        if re.search(r'\bjoin\b', true_sql_norm, re.IGNORECASE):
            complex_count += 1
            simple_query = False
        else:
            simple_count += 1
            simple_query = True

        # Exact match check
        if pred_sql_norm == true_sql_norm:
            exact_match += 1

            if simple_query:
                simple_exact_match += 1
            else:
                complex_exact_match += 1


        # Execution match check
        try:
            db_path = os.path.join(db_dir, f"{db_id}/{db_id}.sqlite")
            pred_results = execute_sql(pred_sql, db_path)
            true_results = execute_sql(true_sql, db_path)

            if str(pred_results):
                execution_true += 1

            if str(pred_results) == str(true_results):
                execution_match += 1

                if simple_query:
                    simple_execution_match += 1
                else:
                    complex_execution_match += 1
        except:
            pass

    # Calculate metrics
    exact_match_acc = exact_match / total
    execution_acc = execution_match / total
    execution_true_acc = execution_true / total
    simple_exact_match_acc = simple_exact_match / simple_count
    simple_execution_acc = simple_execution_match / simple_count
    complex_exact_match_acc = complex_exact_match / complex_count
    complex_execution_acc = complex_execution_match / complex_count


    print(f"Exact Match Accuracy: {exact_match_acc:.4f}")
    print(f"Execution Match Accuracy: {execution_acc:.4f}")
    print(f"Execution True Accuracy: {execution_true_acc:.4f}")
    print(f"Simple Count: {simple_count}")
    print(f"Simple Exact Match Accuracy: {simple_exact_match_acc:.4f}")
    print(f"Simple Execution Match Accuracy: {simple_execution_acc:.4f}")
    print(f"Complex Count: {complex_count}")
    print(f"Complex Exact Match Accuracy: {complex_exact_match_acc:.4f}")
    print(f"Complex Execution Match Accuracy: {complex_execution_acc:.4f}")

    return {
        "exact_match": exact_match_acc,
        "execution_match": execution_acc,
        "execution_true": execution_true_acc,
        "simple_count": simple_count,
        "simple_exact_match": simple_exact_match_acc,
        "simple_execution_match": simple_execution_acc,
        "complex_count": complex_count,
        "complex_exact_match": complex_exact_match_acc,
        "complex_execution_match": complex_execution_acc
    }

# %%
print("Evaluating on validation set...")
val_metrics = evaluate_model(model, tokenizer, val_dataset, text_schema_dict, dataset_dir)
# Out:
# Evaluating on validation set...
# Evaluating:   0%|          | 0/665 [00:00<?, ?it/s]
# True SELECT eid ,  name FROM Employee ORDER BY salary DESC LIMIT 1
# Pred SQL: Show the ID and name of the employee with maximum salary. Table: flight (flno (number) [PK], origin (text), destination (text), distance (number), departure_date (time), arrival_date (time), price (number), aid (number) [FK -> aircraft.aid]) Table: aircraft (aid (number) [PK] [FK -> flight.aid], name (text), distance (number)) Table: employee (eid (
# True SELECT t3.customer_details FROM claim_headers AS t1 JOIN policies AS t2 ON t1.policy_id  =  t2.policy_id JOIN customers AS t3 ON t2.customer_id  =  t3.customer_id WHERE t1.amount_piad  =  (SELECT min(amount_piad) FROM claim_headers)
# Pred SQL: Which customer made the smallest amount of claim in one claim? Return the customer details. Table: Customers (Customer_ID (number) [PK] [FK -> Policies.Customer_ID], Customer_Details (text)) Table: Staff (Staff_ID (number) [PK] [FK -> Claims_Documents.Created_by_Staff_ID], Staff_Details (text)) Table: Policies (Policy_ID
# True SELECT count(*) FROM College
# Pred SQL: Wie viele verschiedene Colleges gibt es?
# True SELECT Festival_Name FROM festival_detail WHERE YEAR  =  2007
# Pred Table: festival_detail (Festival_ID (number) [PK] [FK -> nomination.Festival_ID], Festival_Name (text), Chair_Name (text), Location (text), Year (number), Num_of_Audience (number)) Table: artwork (Artwork_ID (number) [PK] [FK -> nomination.Artwork_ID], Type (text), Name (text)) Table: nomination (Artwork_ID (number) [
# True SELECT allergytype FROM Allergy_type WHERE allergy  =  "Cat"
# Pred SQL: Was ist die Art der Allergie Katze?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3074892366.py in <cell line: 0>()
#       1 print("Evaluating on validation set...")
# ----> 2 val_metrics = evaluate_model(model, tokenizer, val_dataset, text_schema_dict, dataset_dir)
#
# /tmp/ipython-input-3415559184.py in evaluate_model(model, tokenizer, val_dataset, schema_dict, db_dir)
#      36
#      37         with torch.no_grad():
# ---> 38             outputs = model.generate(
#      39                 input_ids=input_ids,
#      40                 max_length=128,
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2651             )
#    2652             # 12. run beam sample
# -> 2653             result = self._beam_search(
#    2654                 input_ids,
#    2655                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _beam_search(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    4096             model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    4097
# -> 4098             model_outputs = self(**model_inputs, return_dict=True)
#    4099
#    4100             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1760
#    1761         # Decode
# -> 1762         decoder_outputs = self.decoder(
#    1763             input_ids=decoder_input_ids,
#    1764             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1090                 all_hidden_states = all_hidden_states + (hidden_states,)
#    1091
# -> 1092             layer_outputs = layer_module(
#    1093                 hidden_states,
#    1094                 causal_mask,
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      92
#      93             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94         return super().__call__(*args, **kwargs)
#      95
#      96
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict, cache_position)
#     729
#     730         # Apply Feed Forward layer
# --> 731         hidden_states = self.layer[-1](hidden_states)
#     732
#     733         # clamp inf values to enable fp16 training
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states)
#     339
#     340     def forward(self, hidden_states):
# --> 341         forwarded_states = self.layer_norm(hidden_states)
#     342         forwarded_states = self.DenseReluDense(forwarded_states)
#     343         hidden_states = hidden_states + self.dropout(forwarded_states)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states)
#     256
#     257         # convert into half-precision if necessary
# --> 258         if self.weight.dtype in [torch.float16, torch.bfloat16]:
#     259             hidden_states = hidden_states.to(self.weight.dtype)
#     260
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1913     # on `torch.nn.Module` and all its subclasses is largely disabled as a result. See:
#    1914     # https://github.com/pytorch/pytorch/pull/115074
# -> 1915     def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#    1916         if "_parameters" in self.__dict__:
#    1917             _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:

# %%
print("Evaluating on test set...")
val_metrics = evaluate_model(model, tokenizer, test_dataset, text_schema_dict, dataset_dir)
# Out:
# Evaluating on test set...
# Evaluating:   0%|          | 0/666 [00:00<?, ?it/s]
# Exact Match Accuracy: 0.2943
# Execution Match Accuracy: 0.4249
# Execution True Accuracy: 1.0000
# Simple Count: 399
# Simple Exact Match Accuracy: 0.4712
# Simple Execution Match Accuracy: 0.5815
# Complex Count: 267
# Complex Exact Match Accuracy: 0.0300
# Complex Execution Match Accuracy: 0.1910
